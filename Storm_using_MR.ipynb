# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavichintapalli/Windstorm_Prediction/blob/master/Storm_using_MR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Ammulu\\Desktop\\datasets'

# %%
os.chdir("C:/Users/Ammulu/Desktop/datasets")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
weather=pd.read_csv("weather.csv")
weather
# Out:
#      Rainfall  Evaporation  Sunshine  WindGustSpeed  WindSpeed9am  \
# 0         0.0          3.4       6.3             30             6
# 1         3.6          4.4       9.7             39             4
# 2         3.6          5.8       3.3             85             6
# 3        39.8          7.2       9.1             54            30
# 4         2.8          5.6      10.6             50            20
# 5         0.0          5.8       8.2             44            20
# 6         0.2          4.2       8.4             43            19
# 7         0.0          5.6       4.6             41            11
# 8         0.0          4.0       4.1             48            19
# 9        16.2          5.4       7.7             31             7
# 10        0.0          4.2      11.9             30             6
# 11        0.2          7.2      12.5             41             2
# 12        0.0          7.2      13.0             30             6
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 16 columns):
# Rainfall         366 non-null float64
# Evaporation      366 non-null float64
# Sunshine         366 non-null float64
# WindGustSpeed    366 non-null int64
# WindSpeed9am     366 non-null int64
# WindSpeed3pm     366 non-null int64
# Humidity9am      366 non-null int64
# Humidity3pm      366 non-null int64
# Pressure9am      366 non-null float64
# Pressure3pm      366 non-null float64
# Cloud9am         366 non-null int64
# Cloud3pm         366 non-null int64
# Temp9am          366 non-null float64
# Temp3pm          366 non-null float64
# RainToday        366 non-null object
# RISK_MM          366 non-null float64
# dtypes: float64(8), int64(7), object(1)
# memory usage: 45.8+ KB

# %%
sns.countplot(x='WindSpeed9am',data=weather)

# %%
sns.countplot(x='WindSpeed3pm',data=weather)

# %%
weather.describe()
# Out:
#          Rainfall  Evaporation    Sunshine  WindGustSpeed  WindSpeed9am  \
# count  366.000000   366.000000  366.000000     366.000000    366.000000
# mean     1.428415     4.521858    7.897814      39.841530      9.658470
# std      4.225800     2.669383    3.463705      13.023983      7.875453
# min      0.000000     0.200000    0.000000      13.000000      0.000000
# 25%      0.000000     2.200000    6.000000      31.000000      6.000000
# 50%      0.000000     4.200000    8.500000      39.000000      7.000000
# 75%      0.200000     6.400000   10.500000      46.000000     13.000000
# max     39.800000    13.800000   13.600000      98.000000     41.000000
#
#        WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# count    366.000000   366.000000   366.000000   366.000000   366.000000
# mean      17.986339    72.035519    44.519126  1019.709016  1016.810383
# std        8.856997    13.137058    16.850947     6.686212     6.469422
# ...

# %%
features=weather.columns
for i in range(len(features)):
    figure = plt.figure()
    ax=sns.boxplot(x='WindSpeed9am', y=features[i],data=weather)

# %%
features=weather.columns
for i in range(len(features)):
    figure = plt.figure()
    ax=sns.boxplot(x='WindSpeed3pm', y=features[i],data=weather)

# %%
weather['WindGustSpeed'].hist(bins=100)

# %%
weather['WindSpeed9am'].hist(bins=100)

# %%
weather['WindSpeed3pm'].hist(bins=100)

# %%
weather['Evaporation'].hist(bins=100)

# %%
correlation=weather.corr()
plt.figure(figsize=(12,6))
sns.heatmap(correlation,annot=True,linewidths=0,vmin=-1,cmap="RdBu_r")

# %%
mean1=weather['Rainfall'].mean()
mean1
# Out:
# 1.4284153005464482

# %%
A=weather['Sunshine']
B=weather['Rainfall']
plt.plot(B,A,'o')
plt.ylabel("Rainfall")
plt.xlabel("Sunshine")
plt.axhline(mean1, color='r', linestyle='-')
sns.regplot(x='Sunshine', y='Rainfall', data=weather)
# Out:
# C:\Users\Ammulu\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
mean2=weather['WindGustSpeed'].mean()
mean2
# Out:
# 39.84153005464481

# %%
C=weather['WindGustSpeed']
plt.plot(C,A,'o')
plt.ylabel("WindGustSpeed")
plt.xlabel("Sunshine")
plt.axhline(mean2, color='r', linestyle='-')
sns.regplot(x='Sunshine', y='WindGustSpeed', data=weather)

# %%
mean3=weather['WindSpeed9am'].mean()
mean3
# Out:
# 9.658469945355192

# %%
D=weather['WindSpeed9am']
plt.plot(D,C,'o')
plt.ylabel("WindSpeed9am")
plt.xlabel("WindGustSpeed")
plt.axhline(mean3, color='r', linestyle='-')
sns.regplot(x='WindGustSpeed', y='WindSpeed9am', data=weather)

# %%
mean4=weather['WindSpeed3pm'].mean()
mean4
# Out:
# 17.98633879781421

# %%
E=weather['WindSpeed3pm']
plt.plot(E,C,'o')
plt.ylabel("WindSpeed3pm")
plt.xlabel("WindGustSpeed")
plt.axhline(mean4, color='r', linestyle='-')
sns.regplot(x='WindGustSpeed', y='WindSpeed3pm', data=weather)

# %%
F=weather['Pressure3pm']
plt.plot(D,F,'o')
plt.ylabel("WindSpeed3pm")
plt.xlabel("Pressure3pm")
plt.axhline(mean4, color='r', linestyle='-')
sns.regplot(x='Pressure3pm', y='WindSpeed3pm', data=weather)

# %%
mean5=weather['Cloud9am'].mean()
mean5
# Out:
# 3.890710382513661

# %%
mean6=weather['Cloud3pm'].mean()
mean6
# Out:
# 4.024590163934426

# %%
a=weather['Cloud9am']
b=weather['Rainfall']
plt.plot(b,a,'o')
plt.ylabel("Rainfall")
plt.xlabel("Cloud9am")
plt.axhline(mean5, color='r', linestyle='-')
sns.regplot(x='Cloud9am', y='Rainfall', data=weather)

# %%
c=weather['Cloud3pm']
plt.plot(b,c,'o')
plt.ylabel("Rainfall")
plt.xlabel("Cloud3pm")
plt.axhline(mean6, color='r', linestyle='-')
sns.regplot(x='Cloud3pm', y='Rainfall', data=weather)

# %%
plt.plot(E,c,'o')
plt.ylabel("WindSpeed3pm")
plt.xlabel("Cloud3pm")
plt.axhline(mean4, color='r', linestyle='-')
sns.regplot(x='Cloud3pm', y='WindSpeed3pm', data=weather)

# %%
X = weather[["WindGustSpeed","Cloud3pm","Sunshine","Temp3pm","Evaporation"]]
y = weather["WindSpeed3pm"]

# %%
import statsmodels.api as sm
model=sm.OLS(y,X).fit()

# %%
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           WindSpeed3pm   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     755.8
# Date:                Tue, 18 Jun 2019   Prob (F-statistic):          9.27e-189
# Time:                        23:01:06   Log-Likelihood:                -1170.1
# No. Observations:                 366   AIC:                             2350.
# Df Residuals:                     361   BIC:                             2370.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2, random_state=0)

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
accuracy=model.score(X_train,y_train)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.5726399697056792

# %%
#Evaluating the model 
from sklearn.metrics import mean_squared_error, r2_score



import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)

print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance
# --------------------------------------
# RMSE is 5.9186623079928875
# R2 score is 0.5522223716418133
